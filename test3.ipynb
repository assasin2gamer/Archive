# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from itertools import combinations, islice
from sklearn.decomposition import FastICA
from concurrent.futures import ThreadPoolExecutor, as_completed
from numba import njit
import cupy as cp

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# --- Workaround for torch_geometric compatibility ---
if not hasattr(torch.serialization, 'add_safe_globals'):
    torch.serialization.add_safe_globals = lambda x: None

from torch_geometric.nn import GATConv
from sklearn.metrics import r2_score
from sklearn.metrics.pairwise import cosine_similarity

# ===================== Propagation Graph Implementation =====================
@njit
def cost(a, b):
    return abs(a - b)

@njit
def compute_d_matrix(s, t):
    T = s.shape[0]
    D = np.empty((T, T), dtype=np.float64)
    D[0, 0] = cost(s[0], t[0])
    for j in range(1, T):
        D[0, j] = D[0, j-1] + cost(s[0], t[j])
    for i in range(1, T):
        D[i, 0] = D[i-1, 0] + cost(s[i], t[0])
    for i in range(1, T):
        for j in range(1, T):
            a_val = D[i-1, j]
            b_val = D[i, j-1]
            c_val = D[i-1, j-1]
            D[i, j] = min(a_val, b_val, c_val) + cost(s[i], t[j])
    return D

@njit
def compute_F_matrix(s, t, D):
    T = s.shape[0]
    F = np.zeros((T, T), dtype=np.float64)
    F[0, 0] = 1.0
    for i in range(T):
        for j in range(T):
            if i == 0 and j == 0:
                continue
            total = 0.0
            c = cost(s[i], t[j])
            if i > 0 and abs(D[i, j] - (D[i-1, j] + c)) < 1e-8:
                total += F[i-1, j]
            if j > 0 and abs(D[i, j] - (D[i, j-1] + c)) < 1e-8:
                total += F[i, j-1]
            if i > 0 and j > 0 and abs(D[i, j] - (D[i-1, j-1] + c)) < 1e-8:
                total += F[i-1, j-1]
            F[i, j] = total
    return F

@njit
def compute_B_matrix(s, t, D):
    T = s.shape[0]
    B = np.zeros((T, T), dtype=np.float64)
    B[T-1, T-1] = 1.0
    for i in range(T-1, -1, -1):
        for j in range(T-1, -1, -1):
            if i == T-1 and j == T-1:
                continue
            total = 0.0
            if i+1 < T and abs(D[i+1, j] - (D[i, j] + cost(s[i+1], t[j]))) < 1e-8:
                total += B[i+1, j]
            if j+1 < T and abs(D[i, j+1] - (D[i, j] + cost(s[i], t[j+1]))) < 1e-8:
                total += B[i, j+1]
            if i+1 < T and j+1 < T and abs(D[i+1, j+1] - (D[i, j] + cost(s[i+1], t[j+1]))) < 1e-8:
                total += B[i+1, j+1]
            B[i, j] = total
    return B

@njit
def avg_time_delay(s, t):
    T = s.shape[0]
    D = compute_d_matrix(s, t)
    F = compute_F_matrix(s, t, D)
    B = compute_B_matrix(s, t, D)
    total_delay = 0.0
    for i in range(1, T):
        for j in range(1, T):
            c = cost(s[i], t[j])
            if abs(D[i, j] - (D[i-1, j-1] + c)) < 1e-8:
                total_delay += (j - i) * F[i-1, j-1] * B[i, j]
    num_alignments = B[0, 0]
    if num_alignments == 0:
        return 0.0
    return total_delay / num_alignments

def avg_time_delay_gpu(s, t):
    s_gpu = cp.asarray(s)
    t_gpu = cp.asarray(t)
    T = s_gpu.shape[0]
    D_gpu = cp.zeros((T, T), dtype=cp.float64)
    D_gpu[0, 0] = cp.abs(s_gpu[0] - t_gpu[0])
    for j in range(1, T):
        D_gpu[0, j] = D_gpu[0, j-1] + cp.abs(s_gpu[0] - t_gpu[j])
    for i in range(1, T):
        D_gpu[i, 0] = D_gpu[i-1, 0] + cp.abs(s_gpu[i] - t_gpu[0])
    for i in range(1, T):
        for j in range(1, T):
            D_gpu[i, j] = cp.minimum(cp.minimum(D_gpu[i-1, j], D_gpu[i, j-1]),
                                       D_gpu[i-1, j-1]) + cp.abs(s_gpu[i] - t_gpu[j])
    D = cp.asnumpy(D_gpu)
    return avg_time_delay(s, t)

def build_propagation_graph(signal_list):
    """
    Construct a propagation graph from a list of stock signals.
    Each signal is a 1D numpy array.
    Returns:
        graph: dict mapping stock index to list of neighbor indices.
        delays: dict mapping (i, j) to average delay.
    """
    N = len(signal_list)
    edges = []
    delays = {}
    for i in range(N):
        for j in range(i+1, N):
            delay_val = avg_time_delay(np.array(signal_list[i]), np.array(signal_list[j]))
            if np.isclose(delay_val, 0.0):
                continue
            if delay_val > 0:
                edges.append((i, j))
                delays[(i, j)] = delay_val
            else:
                edges.append((j, i))
                delays[(j, i)] = -delay_val
    graph = {}
    for (u, v) in edges:
        graph.setdefault(u, []).append(v)
    return graph, delays

def draw_graph(graph, delays, title="Propagation Graph", filename="graph.png"):
    G = nx.DiGraph()
    for u, vs in graph.items():
        for v in vs:
            G.add_edge(u, v, weight=delays.get((u, v), 0))
    pos = nx.spring_layout(G, seed=42)
    plt.figure(figsize=(10, 8))
    nx.draw(G, pos, with_labels=True, node_color="lightblue", arrowstyle="->", arrowsize=20)
    edge_labels = {(u, v): f"{data['weight']:.2f}" for u, v, data in G.edges(data=True)}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')
    plt.title(title)
    plt.axis("off")
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()

def convert_prop_graph_to_edge_tensors(delays):
    """
    Convert the delays dictionary into edge_index and edge_weight tensors.
    We use exp(-delay) as weight.
    """
    edges = []
    weights = []
    for (u, v), delay in delays.items():
        edges.append([u, v])
        weights.append(np.exp(-delay))
    edge_index = torch.tensor(np.array(edges).T, dtype=torch.long)
    edge_weight = torch.tensor(weights, dtype=torch.float)
    return edge_index, edge_weight

# ===================== Feature Engineering & Dataset =====================
def compute_features(prices, window=5):
    """
    Compute log return, rolling mean, and rolling std.
    Returns a DataFrame with MultiIndex columns (stock, feature).
    """
    log_ret = np.log(prices) - np.log(prices.shift(1))
    rolling_mean = log_ret.rolling(window=window).mean()
    rolling_std = log_ret.rolling(window=window).std()
    
    arrays = []
    for stock in prices.columns:
        for feat in ['log', 'mean', 'std']:
            arrays.append((stock, feat))
    col_index = pd.MultiIndex.from_tuples(arrays, names=['stock', 'feature'])
    feature_df = pd.DataFrame(index=prices.index, columns=col_index)
    for stock in prices.columns:
        feature_df[(stock, 'log')] = log_ret[stock]
        feature_df[(stock, 'mean')] = rolling_mean[stock]
        feature_df[(stock, 'std')] = rolling_std[stock]
    feature_df = feature_df.dropna()
    return feature_df

class StockFeatureDataset(Dataset):
    def __init__(self, feature_df, window_size):
        """
        feature_df: DataFrame with MultiIndex columns (stock, feature)
        window_size: number of historical days.
        For each sample, for each stock, extract a window of features (shape: (window_size, num_features)),
        flatten it, and use as input.
        Target: next-day log return for each stock.
        """
        self.feature_df = feature_df
        self.window_size = window_size
        self.stocks = feature_df.columns.levels[0].tolist()
        self.features = feature_df.columns.levels[1].tolist()
        self.num_features = len(self.features)
        self.num_stocks = len(self.stocks)
        self.num_samples = feature_df.shape[0] - window_size
    def __len__(self):
        return self.num_samples
    def __getitem__(self, idx):
        X_list = []
        targets = []
        for stock in self.stocks:
            stock_data = self.feature_df[stock].iloc[idx: idx + self.window_size].values
            X_list.append(stock_data.flatten())
            targets.append(self.feature_df[stock].iloc[idx + self.window_size]['log'])
        X = np.vstack(X_list)
        y = np.array(targets)
        return torch.tensor(X, dtype=torch.float), torch.tensor(y, dtype=torch.float)

# ===================== KAN Model Definition =====================
class StockKAN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=4):
        super(StockKAN, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU()
        )
        self.gat = GATConv(hidden_dim, hidden_dim, heads=heads, concat=False)
        self.predictor = nn.Sequential(
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )
    def forward(self, x, edge_index, edge_weight=None):
        x = self.encoder(x)
        x = self.gat(x, edge_index)
        out = self.predictor(x)
        return out

# ===================== Backtesting Function for All Stocks =====================
def backtest_all_stocks(model, test_dataset, edge_index_prop, edge_weight_prop, device, output_folder):
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=8, pin_memory=True)
    model.eval()
    predictions = []
    actuals = []
    with torch.no_grad():
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)
            batch_size, num_stocks, input_dim = X.shape
            X_reshaped = X.view(-1, input_dim)
            out = model(X_reshaped, edge_index_prop, edge_weight_prop)
            out = out.view(batch_size, num_stocks, -1)
            predictions.append(out.squeeze().cpu().numpy())
            actuals.append(y.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)
    
    portfolio_metrics = ""
    # Generate and save PnL and portfolio statistics for each stock
    for stock_idx, stock_name in enumerate(test_dataset.stocks):
        stock_preds = predictions[:, stock_idx]
        stock_actuals = actuals[:, stock_idx]
        rmse = np.sqrt(np.mean((stock_preds - stock_actuals)**2))
        r2 = r2_score(stock_actuals, stock_preds)
        metrics_str = f"Stock: {stock_name}\n  RMSE: {rmse:.6f}\n  R^2: {r2:.6f}\n"
        print(f"Backtest metrics for {stock_name}:")
        print(metrics_str)
        
        # Correlation scatter plot
        plt.figure(figsize=(8, 6))
        plt.scatter(stock_actuals, stock_preds, alpha=0.6)
        plt.xlabel("Actual Returns")
        plt.ylabel("Predicted Returns")
        plt.title(f"Correlation Scatter for {stock_name} (Backtest)")
        plt.grid(True)
        plt.tight_layout()
        corr_filename = os.path.join(output_folder, f"backtest_correlation_{stock_name}.png")
        plt.savefig(corr_filename)
        plt.close()
        print(f"Saved backtest correlation plot to {corr_filename}")
        
        # Portfolio metrics
        mean_return = np.mean(stock_actuals)
        std_return = np.std(stock_actuals)
        annualized_vol = std_return * np.sqrt(252)
        sharpe_ratio = (mean_return / std_return) * np.sqrt(252) if std_return != 0 else 0.0
        metrics_str += (f"  Mean Daily Return: {mean_return:.6f}\n" +
                        f"  Daily Return Std Dev: {std_return:.6f}\n" +
                        f"  Annualized Volatility: {annualized_vol:.6f}\n" +
                        f"  Sharpe Ratio: {sharpe_ratio:.6f}\n\n")
        print(f"Backtest Portfolio Metrics for {stock_name}:\n"
              f"  Mean Daily Return: {mean_return:.6f}\n"
              f"  Daily Return Std Dev: {std_return:.6f}\n"
              f"  Annualized Volatility: {annualized_vol:.6f}\n"
              f"  Sharpe Ratio: {sharpe_ratio:.6f}")
        
        # Plot cumulative PnL
        positions = np.sign(stock_preds)
        daily_pnl = positions * stock_actuals
        cumulative_pnl = np.cumsum(daily_pnl)
        plt.figure(figsize=(10, 5))
        plt.plot(cumulative_pnl, marker='o', linestyle='-', label="Cumulative PnL")
        plt.xlabel("Test Sample Index (Days)")
        plt.ylabel("Cumulative PnL")
        plt.title(f"PnL Chart for {stock_name} (Backtest)")
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        pnl_filename = os.path.join(output_folder, f"backtest_pnl_{stock_name}.png")
        plt.savefig(pnl_filename)
        plt.close()
        print(f"Saved backtest PnL chart to {pnl_filename}")
        
        portfolio_metrics += metrics_str

    # Save portfolio metrics to a text file in the graphs folder
    metrics_file = os.path.join(output_folder, "portfolio_metrics.txt")
    with open(metrics_file, "w") as f:
        f.write(portfolio_metrics)
    print(f"Saved portfolio metrics to {metrics_file}")

# ===================== Main Pipeline =====================
def main():
    # Load price data
    df = pd.read_csv('./data/global_titans.csv')
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    stocks = df.columns.tolist()
    
    # Compute features: log return, rolling mean, and rolling std (window=5)
    features_df = compute_features(df, window=5)
    
    # Split into training and testing sets (first half for training, second half for testing)
    T = features_df.shape[0]
    train_features = features_df.iloc[:T//2]
    test_features = features_df.iloc[T//2:]
    
    # For propagation graph, use training log returns (from features)
    train_returns = train_features.xs('log', level='feature', axis=1)
    train_data = train_returns.values
    n_components = min(3, train_data.shape[1])
    ica = FastICA(n_components=n_components, random_state=0, max_iter=100, tol=1e-2)
    try:
        ica.fit(train_data)
    except Exception as e:
        print("FastICA failed on training data:", e)
        return
    
    # Build propagation graph using the provided implementation:
    # Process data in windows (prop_window_size=30) over entire dataset
    prop_window_size = 30
    num_windows = df.shape[0] // prop_window_size
    max_triplets = 1000
    all_window_avgs = []
    
    def process_window_prop(w):
        window_df = df.iloc[w*prop_window_size : (w+1)*prop_window_size]
        pair_delays = {}
        for triplet in islice(combinations(stocks, 3), max_triplets):
            data = window_df[list(triplet)].values  # shape: (prop_window_size, 3)
            n_components_local = 3
            ica_local = FastICA(n_components=n_components_local, random_state=0, max_iter=100, tol=1e-2)
            try:
                S = ica_local.fit_transform(data)
            except Exception:
                print("Failed to converge")
                continue
            A = ica_local.mixing_
            best_comp = None
            best_spread = np.inf
            for k in range(n_components_local):
                spread = np.max(A[:, k]) - np.min(A[:, k])
                if spread < best_spread:
                    best_spread = spread
                    best_comp = k
            rec_signals = {}
            for idx, stock in enumerate(triplet):
                rec_signal = A[idx, best_comp] * S[:, best_comp]
                rec_signals[stock] = rec_signal
            for stock1, stock2 in combinations(triplet, 2):
                delay_val = avg_time_delay(rec_signals[stock1], rec_signals[stock2])
                if np.isclose(delay_val, 0.0):
                    continue
                if delay_val > 0:
                    key = (stock1, stock2)
                    val = delay_val
                else:
                    key = (stock2, stock1)
                    val = -delay_val
                pair_delays.setdefault(key, []).append(val)
        window_avg = {pair: np.mean(vals) for pair, vals in pair_delays.items()}
        return window_avg
    
    with ThreadPoolExecutor(max_workers=4) as executor:
        futures = {executor.submit(process_window_prop, w): w for w in range(num_windows)}
        for future in as_completed(futures):
            try:
                result = future.result()
                all_window_avgs.append(result)
            except Exception as e:
                print("A window failed:", e)
    
    # Aggregate delays over windows
    aggregate_delays = {}
    for window_avg in all_window_avgs:
        for pair, delay_val in window_avg.items():
            if pair in aggregate_delays:
                s, cnt = aggregate_delays[pair]
                aggregate_delays[pair] = (s + delay_val, cnt + 1)
            else:
                aggregate_delays[pair] = (delay_val, 1)
    cumulative_avg = {pair: s/cnt for pair, (s, cnt) in aggregate_delays.items()}
    
    # Build propagation graph dictionary from cumulative delays
    prop_graph = {stock: [] for stock in stocks}
    for (u, v), avg_delay in cumulative_avg.items():
        prop_graph.setdefault(u, []).append(v)
    
    # Draw and save the final propagation graph and delays CSV
    output_folder = "graphs"
    os.makedirs(output_folder, exist_ok=True)
    final_graph_file = os.path.join(output_folder, "final_cumulative_prop_graph.png")
    draw_graph(prop_graph, cumulative_avg, title="Final Cumulative Propagation Graph", filename=final_graph_file)
    print(f"Saved final propagation graph to {final_graph_file}")
    final_df = pd.DataFrame([(u, v, avg_delay) for (u, v), avg_delay in cumulative_avg.items()],
                            columns=["Stock1", "Stock2", "AvgDelay"])
    final_df.to_csv(os.path.join(output_folder, "final_cumulative_delays.csv"), index=False)
    print("Saved cumulative propagation delays CSV.")
    
    # Convert propagation graph delays into edge tensors.
    def convert_prop_graph_to_edge_tensors(delays):
        edges = []
        weights = []
        for (u, v), delay in delays.items():
            edges.append([stocks.index(u), stocks.index(v)])
            weights.append(np.exp(-delay))
        edge_index = torch.tensor(np.array(edges).T, dtype=torch.long)
        edge_weight = torch.tensor(weights, dtype=torch.float)
        return edge_index, edge_weight

    edge_index_prop, edge_weight_prop = convert_prop_graph_to_edge_tensors(cumulative_avg)
    print("Propagation graph edges (tensor):", edge_index_prop.shape[1])
    
    # Create datasets using the multi-feature DataFrame
    window_size = 60
    train_dataset = StockFeatureDataset(train_features, window_size)
    test_dataset = StockFeatureDataset(test_features, window_size)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=8, pin_memory=True)
    
    # Input dimension = window_size * number of features (3)
    input_dim = window_size * 3
    model = StockKAN(input_dim=input_dim, hidden_dim=64, output_dim=1, heads=4)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)
    model.to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    
    # --- Training improvements for speed:
    # 1. Process entire batches at once.
    # 2. Move edge tensors to the device outside the loop.
    edge_index_prop = edge_index_prop.to(device)
    edge_weight_prop = edge_weight_prop.to(device)
    
    epochs = 50
    model.train()
        
    # Initialize AMP GradScaler for mixed precision training
    scaler = torch.amp.GradScaler()
    for epoch in range(epochs):
        epoch_loss = 0.0
        for X, y in train_loader:
            X = X.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                batch_size, num_stocks, input_dim = X.shape
                X_reshaped = X.view(-1, input_dim)
                out = model(X_reshaped, edge_index_prop, edge_weight_prop)
                out = out.view(batch_size, num_stocks, -1)
                loss = criterion(out.squeeze(), y)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            epoch_loss += loss.item()
        print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss/len(train_loader):.6f}")
    
    # Evaluate on test set (ensuring no training data is used)
    model.eval()
    predictions = []
    actuals = []
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=8, pin_memory=True)
    with torch.no_grad():
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)
            batch_size, num_stocks, input_dim = X.shape
            X_reshaped = X.view(-1, input_dim)
            out = model(X_reshaped, edge_index_prop, edge_weight_prop)
            out = out.view(batch_size, num_stocks, -1)
            predictions.append(out.squeeze().cpu().numpy())
            actuals.append(y.cpu().numpy())
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)
    rmse = np.sqrt(np.mean((predictions - actuals)**2))
    print(f"Test RMSE: {rmse:.6f}")
    
    r2 = r2_score(actuals, predictions)
    print(f"Test R^2: {r2:.6f}")
    
    pred_sign = np.sign(predictions)
    actual_sign = np.sign(actuals)
    binary_accuracy = np.mean(pred_sign == actual_sign)
    print(f"Test Binary Accuracy: {binary_accuracy:.6f}")
    
    # Print stock names
    print("Stocks:", stocks)
    
    # Save the model for future backtesting
    model_path = os.path.join("saved_models", "stockkan_model.pth")
    os.makedirs("saved_models", exist_ok=True)
    torch.save(model.state_dict(), model_path)
    print(f"Saved model to {model_path}")
    
    # Backtest and generate PnL and statistics for each stock in the dataset,
    # and save portfolio metrics in a text file.
    print("Starting backtesting on test data for all stocks...")
    backtest_all_stocks(model, test_dataset, edge_index_prop, edge_weight_prop, device, output_folder)

if __name__ == '__main__':
    main()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# ...
#   Mean Daily Return: 0.000881
#   Daily Return Std Dev: 0.021393
#   Annualized Volatility: 0.339599
#   Sharpe Ratio: 0.653564
# Saved backtest PnL chart to graphs/backtest_pnl_ADBE.png
# Backtest metrics for AMZN:
# Stock: AMZN
#   RMSE: 0.021792
#   R^2: -0.126667
#
# Saved backtest correlation plot to graphs/backtest_correlation_AMZN.png
# Backtest Portfolio Metrics for AMZN:
#   Mean Daily Return: 0.000921
#   Daily Return Std Dev: 0.020530
#   Annualized Volatility: 0.325908
#   Sharpe Ratio: 0.712099
# Saved backtest PnL chart to graphs/backtest_pnl_AMZN.png
# Backtest metrics for BMY:
# Stock: BMY
#   RMSE: 0.015939
#   R^2: -0.061904
#
# Saved backtest correlation plot to graphs/backtest_correlation_BMY.png
# Backtest Portfolio Metrics for BMY:
#   Mean Daily Return: -0.000050
#   Daily Return Std Dev: 0.015467
#   Annualized Volatility: 0.245537
#   Sharpe Ratio: -0.051723
# Saved backtest PnL chart to graphs/backtest_pnl_BMY.png
# Backtest metrics for BRK-B:
# Stock: BRK-B
#   RMSE: 0.012838
#   R^2: -0.072082
#
# Saved backtest correlation plot to graphs/backtest_correlation_BRK-B.png
# Backtest Portfolio Metrics for BRK-B:
#   Mean Daily Return: 0.000518
#   Daily Return Std Dev: 0.012399
#   Annualized Volatility: 0.196827
#   Sharpe Ratio: 0.662829
# Saved backtest PnL chart to graphs/backtest_pnl_BRK-B.png
# Backtest metrics for CL=F:
# Stock: CL=F
#   RMSE: 0.029950
#   R^2: -0.160140
#
# Saved backtest correlation plot to graphs/backtest_correlation_CL=F.png
# Backtest Portfolio Metrics for CL=F:
#   Mean Daily Return: 0.000413
#   Daily Return Std Dev: 0.027806
#   Annualized Volatility: 0.441409
#   Sharpe Ratio: 0.236021
# Saved backtest PnL chart to graphs/backtest_pnl_CL=F.png
# Backtest metrics for CMCSA:
# Stock: CMCSA
#   RMSE: 0.016833
#   R^2: -0.104926
#
# Saved backtest correlation plot to graphs/backtest_correlation_CMCSA.png
# Backtest Portfolio Metrics for CMCSA:
#   Mean Daily Return: 0.000234
#   Daily Return Std Dev: 0.016014
#   Annualized Volatility: 0.254214
#   Sharpe Ratio: 0.231679
# Saved backtest PnL chart to graphs/backtest_pnl_CMCSA.png
# Backtest metrics for COST:
# Stock: COST
#   RMSE: 0.014354
#   R^2: -0.071869
#
# Saved backtest correlation plot to graphs/backtest_correlation_COST.png
# Backtest Portfolio Metrics for COST:
#   Mean Daily Return: 0.000903
#   Daily Return Std Dev: 0.013864
#   Annualized Volatility: 0.220087
#   Sharpe Ratio: 1.034435
# Saved backtest PnL chart to graphs/backtest_pnl_COST.png
# Backtest metrics for CRM:
# Stock: CRM
#   RMSE: 0.023414
#   R^2: -0.121737
#
# Saved backtest correlation plot to graphs/backtest_correlation_CRM.png
# Backtest Portfolio Metrics for CRM:
#   Mean Daily Return: 0.000615
#   Daily Return Std Dev: 0.022107
#   Annualized Volatility: 0.350937
#   Sharpe Ratio: 0.441490
# Saved backtest PnL chart to graphs/backtest_pnl_CRM.png
# Backtest metrics for CSCO:
# Stock: CSCO
#   RMSE: 0.016797
#   R^2: -0.093911
#
# Saved backtest correlation plot to graphs/backtest_correlation_CSCO.png
# Backtest Portfolio Metrics for CSCO:
#   Mean Daily Return: 0.000393
#   Daily Return Std Dev: 0.016060
#   Annualized Volatility: 0.254939
#   Sharpe Ratio: 0.388204
# Saved backtest PnL chart to graphs/backtest_pnl_CSCO.png
# Backtest metrics for CVX:
# Stock: CVX
#   RMSE: 0.020887
#   R^2: -0.186935
#
# Saved backtest correlation plot to graphs/backtest_correlation_CVX.png
# Backtest Portfolio Metrics for CVX:
#   Mean Daily Return: 0.000469
#   Daily Return Std Dev: 0.019172
#   Annualized Volatility: 0.304347
#   Sharpe Ratio: 0.388583
# Saved backtest PnL chart to graphs/backtest_pnl_CVX.png
# Backtest metrics for DHR:
# Stock: DHR
#   RMSE: 0.019206
#   R^2: -0.119698
#
# Saved backtest correlation plot to graphs/backtest_correlation_DHR.png
# Backtest Portfolio Metrics for DHR:
#   Mean Daily Return: 0.000842
#   Daily Return Std Dev: 0.018150
#   Annualized Volatility: 0.288126
#   Sharpe Ratio: 0.736358
# Saved backtest PnL chart to graphs/backtest_pnl_DHR.png
# Backtest metrics for DIS:
# Stock: DIS
#   RMSE: 0.018717
#   R^2: -0.098356
#
# Saved backtest correlation plot to graphs/backtest_correlation_DIS.png
# Backtest Portfolio Metrics for DIS:
#   Mean Daily Return: 0.000021
#   Daily Return Std Dev: 0.017859
#   Annualized Volatility: 0.283503
#   Sharpe Ratio: 0.018660
# Saved backtest PnL chart to graphs/backtest_pnl_DIS.png
# Backtest metrics for GLD:
# Stock: GLD
#   RMSE: 0.008946
#   R^2: -0.019662
#
# Saved backtest correlation plot to graphs/backtest_correlation_GLD.png
# Backtest Portfolio Metrics for GLD:
#   Mean Daily Return: 0.000304
#   Daily Return Std Dev: 0.008860
#   Annualized Volatility: 0.140641
#   Sharpe Ratio: 0.544314
# Saved backtest PnL chart to graphs/backtest_pnl_GLD.png
# Backtest metrics for GOOGL:
# Stock: GOOGL
#   RMSE: 0.018511
#   R^2: -0.080237
#
# Saved backtest correlation plot to graphs/backtest_correlation_GOOGL.png
# Backtest Portfolio Metrics for GOOGL:
#   Mean Daily Return: 0.000792
#   Daily Return Std Dev: 0.017811
#   Annualized Volatility: 0.282737
#   Sharpe Ratio: 0.706274
# Saved backtest PnL chart to graphs/backtest_pnl_GOOGL.png
# Backtest metrics for HD:
# Stock: HD
#   RMSE: 0.016509
#   R^2: -0.100468
#
# Saved backtest correlation plot to graphs/backtest_correlation_HD.png
# Backtest Portfolio Metrics for HD:
#   Mean Daily Return: 0.000566
#   Daily Return Std Dev: 0.015737
#   Annualized Volatility: 0.249817
#   Sharpe Ratio: 0.570641
# Saved backtest PnL chart to graphs/backtest_pnl_HD.png
# Backtest metrics for HON:
# Stock: HON
#   RMSE: 0.015400
#   R^2: -0.115247
#
# Saved backtest correlation plot to graphs/backtest_correlation_HON.png
# Backtest Portfolio Metrics for HON:
#   Mean Daily Return: 0.000449
#   Daily Return Std Dev: 0.014582
#   Annualized Volatility: 0.231487
#   Sharpe Ratio: 0.488261
# Saved backtest PnL chart to graphs/backtest_pnl_HON.png
# Backtest metrics for IBM:
# Stock: IBM
#   RMSE: 0.016077
#   R^2: -0.111092
#
# Saved backtest correlation plot to graphs/backtest_correlation_IBM.png
# Backtest Portfolio Metrics for IBM:
#   Mean Daily Return: 0.000251
#   Daily Return Std Dev: 0.015252
#   Annualized Volatility: 0.242114
#   Sharpe Ratio: 0.260817
# Saved backtest PnL chart to graphs/backtest_pnl_IBM.png
# Backtest metrics for INTC:
# Stock: INTC
#   RMSE: 0.023069
#   R^2: -0.133651
#
# Saved backtest correlation plot to graphs/backtest_correlation_INTC.png
# Backtest Portfolio Metrics for INTC:
#   Mean Daily Return: 0.000142
#   Daily Return Std Dev: 0.021667
#   Annualized Volatility: 0.343945
#   Sharpe Ratio: 0.104048
# Saved backtest PnL chart to graphs/backtest_pnl_INTC.png
# Backtest metrics for JNJ:
# Stock: JNJ
#   RMSE: 0.011793
#   R^2: -0.043205
#
# Saved backtest correlation plot to graphs/backtest_correlation_JNJ.png
# Backtest Portfolio Metrics for JNJ:
#   Mean Daily Return: 0.000308
#   Daily Return Std Dev: 0.011546
#   Annualized Volatility: 0.183287
#   Sharpe Ratio: 0.422884
# Saved backtest PnL chart to graphs/backtest_pnl_JNJ.png
# Backtest metrics for KO:
# Stock: KO
#   RMSE: 0.011870
#   R^2: -0.062783
#
# Saved backtest correlation plot to graphs/backtest_correlation_KO.png
# Backtest Portfolio Metrics for KO:
#   Mean Daily Return: 0.000362
#   Daily Return Std Dev: 0.011514
#   Annualized Volatility: 0.182772
#   Sharpe Ratio: 0.499000
# Saved backtest PnL chart to graphs/backtest_pnl_KO.png
# Backtest metrics for LIN:
# Stock: LIN
#   RMSE: 0.015344
#   R^2: -0.066722
#
# Saved backtest correlation plot to graphs/backtest_correlation_LIN.png
# Backtest Portfolio Metrics for LIN:
#   Mean Daily Return: 0.000739
#   Daily Return Std Dev: 0.014856
#   Annualized Volatility: 0.235839
#   Sharpe Ratio: 0.789767
# Saved backtest PnL chart to graphs/backtest_pnl_LIN.png
# Backtest metrics for LLY:
# Stock: LLY
#   RMSE: 0.017899
#   R^2: -0.064795
#
# Saved backtest correlation plot to graphs/backtest_correlation_LLY.png
# Backtest Portfolio Metrics for LLY:
#   Mean Daily Return: 0.001153
#   Daily Return Std Dev: 0.017346
#   Annualized Volatility: 0.275356
#   Sharpe Ratio: 1.055517
# Saved backtest PnL chart to graphs/backtest_pnl_LLY.png
# Backtest metrics for MA:
# Stock: MA
#   RMSE: 0.017845
#   R^2: -0.067226
#
# Saved backtest correlation plot to graphs/backtest_correlation_MA.png
# Backtest Portfolio Metrics for MA:
#   Mean Daily Return: 0.000726
#   Daily Return Std Dev: 0.017274
#   Annualized Volatility: 0.274217
#   Sharpe Ratio: 0.667444
# Saved backtest PnL chart to graphs/backtest_pnl_MA.png
# Backtest metrics for MCD:
# Stock: MCD
#   RMSE: 0.013324
#   R^2: -0.063584
#
# Saved backtest correlation plot to graphs/backtest_correlation_MCD.png
# Backtest Portfolio Metrics for MCD:
#   Mean Daily Return: 0.000540
#   Daily Return Std Dev: 0.012920
#   Annualized Volatility: 0.205093
#   Sharpe Ratio: 0.663695
# Saved backtest PnL chart to graphs/backtest_pnl_MCD.png
# Backtest metrics for MDT:
# Stock: MDT
#   RMSE: 0.015474
#   R^2: -0.102646
#
# Saved backtest correlation plot to graphs/backtest_correlation_MDT.png
# Backtest Portfolio Metrics for MDT:
#   Mean Daily Return: 0.000163
#   Daily Return Std Dev: 0.014736
#   Annualized Volatility: 0.233927
#   Sharpe Ratio: 0.175301
# Saved backtest PnL chart to graphs/backtest_pnl_MDT.png
# Backtest metrics for MRK:
# Stock: MRK
#   RMSE: 0.013992
#   R^2: -0.078515
#
# Saved backtest correlation plot to graphs/backtest_correlation_MRK.png
# Backtest Portfolio Metrics for MRK:
#   Mean Daily Return: 0.000530
#   Daily Return Std Dev: 0.013473
#   Annualized Volatility: 0.213883
#   Sharpe Ratio: 0.623950
# Saved backtest PnL chart to graphs/backtest_pnl_MRK.png
# Backtest metrics for MSFT:
# Stock: MSFT
#   RMSE: 0.018041
#   R^2: -0.104573
#
# Saved backtest correlation plot to graphs/backtest_correlation_MSFT.png
# Backtest Portfolio Metrics for MSFT:
#   Mean Daily Return: 0.001124
#   Daily Return Std Dev: 0.017166
#   Annualized Volatility: 0.272501
#   Sharpe Ratio: 1.039376
# Saved backtest PnL chart to graphs/backtest_pnl_MSFT.png
# Backtest metrics for NEE:
# Stock: NEE
#   RMSE: 0.016465
#   R^2: -0.126070
#
# Saved backtest correlation plot to graphs/backtest_correlation_NEE.png
# Backtest Portfolio Metrics for NEE:
#   Mean Daily Return: 0.000598
#   Daily Return Std Dev: 0.015516
#   Annualized Volatility: 0.246311
#   Sharpe Ratio: 0.611668
# Saved backtest PnL chart to graphs/backtest_pnl_NEE.png
# Backtest metrics for NFLX:
# Stock: NFLX
#   RMSE: 0.030281
#   R^2: -0.172211
#
# Saved backtest correlation plot to graphs/backtest_correlation_NFLX.png
# Backtest Portfolio Metrics for NFLX:
#   Mean Daily Return: 0.000861
#   Daily Return Std Dev: 0.027968
#   Annualized Volatility: 0.443982
#   Sharpe Ratio: 0.488632
# Saved backtest PnL chart to graphs/backtest_pnl_NFLX.png
# Backtest metrics for NKE:
# Stock: NKE
#   RMSE: 0.020077
#   R^2: -0.086225
#
# Saved backtest correlation plot to graphs/backtest_correlation_NKE.png
# Backtest Portfolio Metrics for NKE:
#   Mean Daily Return: 0.000186
#   Daily Return Std Dev: 0.019263
#   Annualized Volatility: 0.305797
#   Sharpe Ratio: 0.153143
# Saved backtest PnL chart to graphs/backtest_pnl_NKE.png
# Backtest metrics for NVDA:
# Stock: NVDA
#   RMSE: 0.032809
#   R^2: -0.149345
#
# Saved backtest correlation plot to graphs/backtest_correlation_NVDA.png
# Backtest Portfolio Metrics for NVDA:
#   Mean Daily Return: 0.002450
#   Daily Return Std Dev: 0.030604
#   Annualized Volatility: 0.485817
#   Sharpe Ratio: 1.270734
# Saved backtest PnL chart to graphs/backtest_pnl_NVDA.png
# Backtest metrics for ORCL:
# Stock: ORCL
#   RMSE: 0.018083
#   R^2: -0.083212
#
# Saved backtest correlation plot to graphs/backtest_correlation_ORCL.png
# Backtest Portfolio Metrics for ORCL:
#   Mean Daily Return: 0.000681
#   Daily Return Std Dev: 0.017375
#   Annualized Volatility: 0.275812
#   Sharpe Ratio: 0.622338
# Saved backtest PnL chart to graphs/backtest_pnl_ORCL.png
# Backtest metrics for PEP:
# Stock: PEP
#   RMSE: 0.012283
#   R^2: -0.054174
#
# Saved backtest correlation plot to graphs/backtest_correlation_PEP.png
# Backtest Portfolio Metrics for PEP:
#   Mean Daily Return: 0.000388
#   Daily Return Std Dev: 0.011963
#   Annualized Volatility: 0.189909
#   Sharpe Ratio: 0.515289
# Saved backtest PnL chart to graphs/backtest_pnl_PEP.png
# Backtest metrics for PFE:
# Stock: PFE
#   RMSE: 0.015280
#   R^2: -0.054866
#
# Saved backtest correlation plot to graphs/backtest_correlation_PFE.png
# Backtest Portfolio Metrics for PFE:
#   Mean Daily Return: 0.000101
#   Daily Return Std Dev: 0.014877
#   Annualized Volatility: 0.236163
#   Sharpe Ratio: 0.108154
# Saved backtest PnL chart to graphs/backtest_pnl_PFE.png
# Backtest metrics for PG:
# Stock: PG
#   RMSE: 0.011846
#   R^2: -0.011761
#
# Saved backtest correlation plot to graphs/backtest_correlation_PG.png
# Backtest Portfolio Metrics for PG:
#   Mean Daily Return: 0.000524
#   Daily Return Std Dev: 0.011777
#   Annualized Volatility: 0.186955
#   Sharpe Ratio: 0.705770
# Saved backtest PnL chart to graphs/backtest_pnl_PG.png
# Backtest metrics for QCOM:
# Stock: QCOM
#   RMSE: 0.024839
#   R^2: -0.126346
#
# Saved backtest correlation plot to graphs/backtest_correlation_QCOM.png
# Backtest Portfolio Metrics for QCOM:
#   Mean Daily Return: 0.000696
#   Daily Return Std Dev: 0.023404
#   Annualized Volatility: 0.371532
#   Sharpe Ratio: 0.472175
# Saved backtest PnL chart to graphs/backtest_pnl_QCOM.png
# Backtest metrics for RTX:
# Stock: RTX
#   RMSE: 0.018762
#   R^2: -0.161000
#
# Saved backtest correlation plot to graphs/backtest_correlation_RTX.png
# Backtest Portfolio Metrics for RTX:
#   Mean Daily Return: 0.000353
#   Daily Return Std Dev: 0.017413
#   Annualized Volatility: 0.276420
#   Sharpe Ratio: 0.322206
# Saved backtest PnL chart to graphs/backtest_pnl_RTX.png
# Backtest metrics for SLV:
# Stock: SLV
#   RMSE: 0.017441
#   R^2: -0.064740
#
# Saved backtest correlation plot to graphs/backtest_correlation_SLV.png
# Backtest Portfolio Metrics for SLV:
#   Mean Daily Return: 0.000287
#   Daily Return Std Dev: 0.016902
#   Annualized Volatility: 0.268313
#   Sharpe Ratio: 0.269890
# Saved backtest PnL chart to graphs/backtest_pnl_SLV.png
# Backtest metrics for T:
# Stock: T
#   RMSE: 0.014996
#   R^2: -0.048096
#
# Saved backtest correlation plot to graphs/backtest_correlation_T.png
# Backtest Portfolio Metrics for T:
#   Mean Daily Return: 0.000188
#   Daily Return Std Dev: 0.014648
#   Annualized Volatility: 0.232535
#   Sharpe Ratio: 0.203364
# Saved backtest PnL chart to graphs/backtest_pnl_T.png
# Backtest metrics for TMO:
# Stock: TMO
#   RMSE: 0.016308
#   R^2: -0.063147
#
# Saved backtest correlation plot to graphs/backtest_correlation_TMO.png
# Backtest Portfolio Metrics for TMO:
#   Mean Daily Return: 0.000678
#   Daily Return Std Dev: 0.015817
#   Annualized Volatility: 0.251079
#   Sharpe Ratio: 0.680367
# Saved backtest PnL chart to graphs/backtest_pnl_TMO.png
# Backtest metrics for TXN:
# Stock: TXN
#   RMSE: 0.018614
#   R^2: -0.091397
#
# Saved backtest correlation plot to graphs/backtest_correlation_TXN.png
# Backtest Portfolio Metrics for TXN:
#   Mean Daily Return: 0.000737
#   Daily Return Std Dev: 0.017818
#   Annualized Volatility: 0.282849
#   Sharpe Ratio: 0.656558
# Saved backtest PnL chart to graphs/backtest_pnl_TXN.png
# Backtest metrics for UNH:
# Stock: UNH
#   RMSE: 0.017512
#   R^2: -0.138774
#
# Saved backtest correlation plot to graphs/backtest_correlation_UNH.png
# Backtest Portfolio Metrics for UNH:
#   Mean Daily Return: 0.000734
#   Daily Return Std Dev: 0.016411
#   Annualized Volatility: 0.260512
#   Sharpe Ratio: 0.710087
# Saved backtest PnL chart to graphs/backtest_pnl_UNH.png
# Backtest metrics for VZ:
# Stock: VZ
#   RMSE: 0.012469
#   R^2: -0.031960
#
# Saved backtest correlation plot to graphs/backtest_correlation_VZ.png
# Backtest Portfolio Metrics for VZ:
#   Mean Daily Return: 0.000156
#   Daily Return Std Dev: 0.012274
#   Annualized Volatility: 0.194843
#   Sharpe Ratio: 0.201579
# Saved backtest PnL chart to graphs/backtest_pnl_VZ.png
# Backtest metrics for WMT:
# Stock: WMT
#   RMSE: 0.013785
#   R^2: -0.040767
#
# Saved backtest correlation plot to graphs/backtest_correlation_WMT.png
# Backtest Portfolio Metrics for WMT:
#   Mean Daily Return: 0.000609
#   Daily Return Std Dev: 0.013512
#   Annualized Volatility: 0.214494
#   Sharpe Ratio: 0.716011
# Saved backtest PnL chart to graphs/backtest_pnl_WMT.png
# Backtest metrics for XOM:
# Stock: XOM
#   RMSE: 0.018987
#   R^2: -0.114908
#
# Saved backtest correlation plot to graphs/backtest_correlation_XOM.png
# Backtest Portfolio Metrics for XOM:
#   Mean Daily Return: 0.000372
#   Daily Return Std Dev: 0.017982
#   Annualized Volatility: 0.285456
#   Sharpe Ratio: 0.328631
# Saved backtest PnL chart to graphs/backtest_pnl_XOM.png
# Saved portfolio metrics to graphs/portfolio_metrics.txt
